# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
Crime = pd.read_csv (r'SouthAfricaCrimeStats_v2.csv')

# %%
Crime.head()
# Out:
#        Province            Station                           Category  \
# 0  Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1       Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2  Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3    Free State          Park Road  All theft not mentioned elsewhere
# 4       Gauteng   Pretoria Central  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       6093       4602       3761       3610       3267       3037
# 2       5341       6093       6316       6803       6035       5761
# 3       5108       4282       3834       3316       3101       3013
# 4       5099       4536       3309       2694       2616       2606
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0       5285       5937       5600       5335       5176
# ...

# %%
K_Crime = Crime[Crime["Category"]=="Murder"]
K_Crime.head(10)
# Out:
#            Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 2028   Western Cape       Nyanga   Murder        282        302        266
# 2379  Kwazulu/Natal      Ntuzuma   Murder        241        254        236
# 2407  Kwazulu/Natal       Inanda   Murder        239        215        192
# 2548   Eastern Cape      Mthatha   Murder        223        143        149
# 2584   Western Cape  Khayelitsha   Murder        219        198        171
# 2893  Kwazulu/Natal       Umlazi   Murder        195        218        194
# 3463  Kwazulu/Natal   Esikhaleni   Murder        157        117         79
# 3560   Western Cape    Gugulethu   Murder        153        161        153
# 3749   Western Cape       Harare   Murder        143        168        175
# 3867  Kwazulu/Natal  Plessislaer   Murder        137        116        130
#
#       2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# ...

# %%
L_Crime = K_Crime[K_Crime["Province"]=="Mpumalanga"] # Extracting KZN in the Dataset
L_Crime.head(10)
# Out:
#          Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 7036   Mpumalanga  Kanyamazane   Murder         57         75         47
# 7316   Mpumalanga   Embalenhle   Murder         54         48         33
# 8252   Mpumalanga       Masoyi   Murder         43         41         32
# 8671   Mpumalanga       Vosman   Murder         39         35         29
# 8759   Mpumalanga       Mhluzi   Murder         38         34         39
# 8825   Mpumalanga        Tonga   Murder         38         27         32
# 9266   Mpumalanga    Kabokweni   Murder         34         41         30
# 9841   Mpumalanga  Piet Retief   Murder         30         29         25
# 10124  Mpumalanga       Ermelo   Murder         28         19         25
# 10280  Mpumalanga      Witbank   Murder         27         28         35
#
#        2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 7036          49         46         30         10         10          6
# ...

# %%
L_Crime.to_csv(r'C:\Users\PHIRIME\Desktop\Phirie\MPeMurder.csv')

# %%
Crime = pd.read_csv('MPeMurder.csv')

# %%
Crime.head()
# Out:
#    Unnamed: 0    Province      Station Category  2005-2006  2006-2007  \
# 0        7036  Mpumalanga  Kanyamazane   Murder         57         75
# 1        7316  Mpumalanga   Embalenhle   Murder         54         48
# 2        8252  Mpumalanga       Masoyi   Murder         43         41
# 3        8671  Mpumalanga       Vosman   Murder         39         35
# 4        8759  Mpumalanga       Mhluzi   Murder         38         34
#
#    2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  \
# 0         47         49         46         30         10         10
# 1         33         44         39         39         42         28
# 2         32         23         23         13         24         24
# 3         29         36         45         33         33         34
# 4         39         31         21         15         16         20
#
#    2013-2014  2014-2015  2015-2016
# 0          6          7          6
# 1         47         66         79
# ...

# %%
Crime.shape
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# (86, 15)

# %%
Crime.head()
# Out:
#    Unnamed: 0    Province      Station Category  2005-2006  2006-2007  \
# 0        7036  Mpumalanga  Kanyamazane   Murder         57         75
# 1        7316  Mpumalanga   Embalenhle   Murder         54         48
# 2        8252  Mpumalanga       Masoyi   Murder         43         41
# 3        8671  Mpumalanga       Vosman   Murder         39         35
# 4        8759  Mpumalanga       Mhluzi   Murder         38         34
#
#    2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  \
# 0         47         49         46         30         10         10
# 1         33         44         39         39         42         28
# 2         32         23         23         13         24         24
# 3         29         36         45         33         33         34
# 4         39         31         21         15         16         20
#
#    2013-2014  2014-2015  2015-2016
# 0          6          7          6
# 1         47         66         79
# ...

# %%
MP_Crimex=Crime.drop(['Station','Unnamed: 0','Province','Category'], axis=1)
MP_Crimex.head()
# Out:
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0         57         75         47         49         46         30
# 1         54         48         33         44         39         39
# 2         43         41         32         23         23         13
# 3         39         35         29         36         45         33
# 4         38         34         39         31         21         15
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0         10         10          6          7          6
# 1         42         28         47         66         79
# 2         24         24         19         20         30
# 3         33         34         42         50         25
# 4         16         20         14         17          9

# %%
MP_Crimex = MP_Crimex.append(MP_Crimex.agg(['sum']))

# %%
MP_Crimex.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 82           0          0          0          0          1          0
# 83           0          4          0          1          2          1
# 84           0          0          1          2          0          0
# 85           0          0          0          0          0          0
# sum        877        858        831        895        864        717
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 82           0          1          4          0          1
# 83           1          0          1          1          1
# 84           1          3          2          3          2
# 85          19         26         23         30         38
# sum        726        693        806        831        859

# %%
head1=(MP_Crimex.loc['sum'])

# %%
head1.head(11)
# Out:
# 2005-2006    877
# 2006-2007    858
# 2007-2008    831
# 2008-2009    895
# 2009-2010    864
# 2010-2011    717
# 2011-2012    726
# 2012-2013    693
# 2013-2014    806
# 2014-2015    831
# 2015-2016    859
# Name: sum, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = head1
s.plot.bar()

plt.show()

# %%
s.plot.line()
plt.show()
