# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
Crime = pd.read_csv (r'SouthAfricaCrimeStats_v2.csv')

# %%
Crime.head(5)
# Out:
#        Province            Station                           Category  \
# 0  Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1       Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2  Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3    Free State          Park Road  All theft not mentioned elsewhere
# 4       Gauteng   Pretoria Central  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       6093       4602       3761       3610       3267       3037
# 2       5341       6093       6316       6803       6035       5761
# 3       5108       4282       3834       3316       3101       3013
# 4       5099       4536       3309       2694       2616       2606
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0       5285       5937       5600       5335       5176
# ...

# %%
K_Crime = Crime[Crime["Category"]=="Murder"]
K_Crime.head(10)
# Out:
#            Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 2028   Western Cape       Nyanga   Murder        282        302        266
# 2379  Kwazulu/Natal      Ntuzuma   Murder        241        254        236
# 2407  Kwazulu/Natal       Inanda   Murder        239        215        192
# 2548   Eastern Cape      Mthatha   Murder        223        143        149
# 2584   Western Cape  Khayelitsha   Murder        219        198        171
# 2893  Kwazulu/Natal       Umlazi   Murder        195        218        194
# 3463  Kwazulu/Natal   Esikhaleni   Murder        157        117         79
# 3560   Western Cape    Gugulethu   Murder        153        161        153
# 3749   Western Cape       Harare   Murder        143        168        175
# 3867  Kwazulu/Natal  Plessislaer   Murder        137        116        130
#
#       2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# ...

# %%
G_Crime = K_Crime[K_Crime["Province"]=="Gauteng"] # Extracting KZN in the Dataset
G_Crime.head(10)
# Out:
#      Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 4409  Gauteng      Tembisa   Murder        116        131        131
# 4655  Gauteng     Hillbrow   Murder        107        105         84
# 4742  Gauteng    Katlehong   Murder        104        108        111
# 5363  Gauteng  Jhb Central   Murder         87         64         75
# 5454  Gauteng   Roodepoort   Murder         85         60         68
# 5780  Gauteng   Westonaria   Murder         78         62         79
# 5897  Gauteng       Moroka   Murder         76         86         86
# 6186  Gauteng      Erasmia   Murder         70         71         69
# 6188  Gauteng     Mamelodi   Murder         70         54         38
# 6276  Gauteng        Jeppe   Murder         69         67         76
#
#       2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 4409        148        122        111         76         78         89
# ...

# %%
G_Crime.to_csv(r'C:\Users\PHIRIME\Desktop\Phirie\GautengMurder.csv')

# %%
Crime = pd.read_csv('GautengMurder.csv')

# %%
Crime.head()
# Out:
#    Unnamed: 0 Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 0        4409  Gauteng      Tembisa   Murder        116        131        131
# 1        4655  Gauteng     Hillbrow   Murder        107        105         84
# 2        4742  Gauteng    Katlehong   Murder        104        108        111
# 3        5363  Gauteng  Jhb Central   Murder         87         64         75
# 4        5454  Gauteng   Roodepoort   Murder         85         60         68
#
#    2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 0        148        122        111         76         78         89
# 1         87         63         50         56         63         67
# 2        113         84         97         85         40         33
# 3         75         51         39         50         53         65
# 4         97         64         55         77         73         94
#
#    2014-2015  2015-2016
# 0         79         94
# 1         58        103
# ...

# %%
Crime.shape
# Out:
# (143, 15)

# %%
Crime.head()
# Out:
#    Unnamed: 0 Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 0        4409  Gauteng      Tembisa   Murder        116        131        131
# 1        4655  Gauteng     Hillbrow   Murder        107        105         84
# 2        4742  Gauteng    Katlehong   Murder        104        108        111
# 3        5363  Gauteng  Jhb Central   Murder         87         64         75
# 4        5454  Gauteng   Roodepoort   Murder         85         60         68
#
#    2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 0        148        122        111         76         78         89
# 1         87         63         50         56         63         67
# 2        113         84         97         85         40         33
# 3         75         51         39         50         53         65
# 4         97         64         55         77         73         94
#
#    2014-2015  2015-2016
# 0         79         94
# 1         58        103
# ...

# %%
Crimex=Crime.drop(['Station','Unnamed: 0','Province','Category'], axis=1)
Crimex.head()
# Out:
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0        116        131        131        148        122        111
# 1        107        105         84         87         63         50
# 2        104        108        111        113         84         97
# 3         87         64         75         75         51         39
# 4         85         60         68         97         64         55
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0         76         78         89         79         94
# 1         56         63         67         58        103
# 2         85         40         33         50         35
# 3         50         53         65         84         75
# 4         77         73         94         86         58

# %%
Crimex = Crimex.append(Crimex.agg(['sum']))

# %%
Crimex.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 139          0          0          0          0          0          0
# 140          0          0          0          0          0          0
# 141          0         51         51         77         40         53
# 142          0          0          0          0          0         37
# sum       3607       3863       3743       3946       3429       3246
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 139          0         29         45         41         43
# 140          0         59         62         53         54
# 141         50         54         54         80         55
# 142         52         69         65         59         68
# sum       2995       2988       3325       3671       3842

# %%
head1=(Crimex.loc['sum'])

# %%
head1.head(11)
# Out:
# 2005-2006    3607
# 2006-2007    3863
# 2007-2008    3743
# 2008-2009    3946
# 2009-2010    3429
# 2010-2011    3246
# 2011-2012    2995
# 2012-2013    2988
# 2013-2014    3325
# 2014-2015    3671
# 2015-2016    3842
# Name: sum, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = head1
s.plot.bar()

plt.show()

# %%
s.plot.line()
plt.show()
