# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
Crime = pd.read_csv (r'SouthAfricaCrimeStats_v2.csv')

# %%
Crime.head(10)
# Out:
#         Province            Station                           Category  \
# 0   Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1        Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2   Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3     Free State          Park Road  All theft not mentioned elsewhere
# 4        Gauteng   Pretoria Central  All theft not mentioned elsewhere
# 5     North West         Rustenburg  All theft not mentioned elsewhere
# 6  Kwazulu/Natal     Durban Central  All theft not mentioned elsewhere
# 7        Gauteng           Brooklyn  All theft not mentioned elsewhere
# 8        Gauteng           Booysens  All theft not mentioned elsewhere
# 9        Gauteng           Hillbrow  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# ...

# %%
K_Crime = Crime[Crime["Category"]=="Murder"]
K_Crime.head(10)
# Out:
#            Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 2028   Western Cape       Nyanga   Murder        282        302        266
# 2379  Kwazulu/Natal      Ntuzuma   Murder        241        254        236
# 2407  Kwazulu/Natal       Inanda   Murder        239        215        192
# 2548   Eastern Cape      Mthatha   Murder        223        143        149
# 2584   Western Cape  Khayelitsha   Murder        219        198        171
# 2893  Kwazulu/Natal       Umlazi   Murder        195        218        194
# 3463  Kwazulu/Natal   Esikhaleni   Murder        157        117         79
# 3560   Western Cape    Gugulethu   Murder        153        161        153
# 3749   Western Cape       Harare   Murder        143        168        175
# 3867  Kwazulu/Natal  Plessislaer   Murder        137        116        130
#
#       2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# ...

# %%
L_Crime = K_Crime[K_Crime["Province"]=="Limpopo"] # Extracting KZN in the Dataset
L_Crime.head(10)
# Out:
#       Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 8692   Limpopo  Mahwelereng   Murder         39         30         23
# 9446   Limpopo      Seshego   Murder         33         57         45
# 9699   Limpopo        Maake   Murder         31         24         20
# 9972   Limpopo     Mankweng   Murder         29         28         37
# 10153  Limpopo  Thohoyandou   Murder         28         40         33
# 10224  Limpopo    Polokwane   Murder         27         22         36
# 10750  Limpopo    Dennilton   Murder         24         19         13
# 11537  Limpopo         Nebo   Murder         20         20         21
# 11561  Limpopo     Motetema   Murder         20         27         12
# 11971  Limpopo  Lebowakgomo   Murder         18         17         15
#
#        2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 8692          25         28         20         24         31         27
# ...

# %%
L_Crime.to_csv(r'C:\Users\PHIRIME\Desktop\Phirie\LimpgMurder.csv')

# %%
Crime = pd.read_csv('LimpgMurder.csv')

# %%
Crime.head()
# Out:
#    Unnamed: 0 Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 0        8692  Limpopo  Mahwelereng   Murder         39         30         23
# 1        9446  Limpopo      Seshego   Murder         33         57         45
# 2        9699  Limpopo        Maake   Murder         31         24         20
# 3        9972  Limpopo     Mankweng   Murder         29         28         37
# 4       10153  Limpopo  Thohoyandou   Murder         28         40         33
#
#    2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 0         25         28         20         24         31         27
# 1         36         55         37         51         41         51
# 2         19         29         26         27         22         27
# 3         27         40         41         44         27         35
# 4         37         36         18         24         29         51
#
#    2014-2015  2015-2016
# 0         21         32
# 1         48         51
# ...

# %%
Crime.shape
# Out:
# (99, 15)

# %%
Crime.head()
# Out:
#    Unnamed: 0 Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 0        8692  Limpopo  Mahwelereng   Murder         39         30         23
# 1        9446  Limpopo      Seshego   Murder         33         57         45
# 2        9699  Limpopo        Maake   Murder         31         24         20
# 3        9972  Limpopo     Mankweng   Murder         29         28         37
# 4       10153  Limpopo  Thohoyandou   Murder         28         40         33
#
#    2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 0         25         28         20         24         31         27
# 1         36         55         37         51         41         51
# 2         19         29         26         27         22         27
# 3         27         40         41         44         27         35
# 4         37         36         18         24         29         51
#
#    2014-2015  2015-2016
# 0         21         32
# 1         48         51
# ...

# %%
L_Crime=Crime.drop(['Station','Unnamed: 0','Province','Category'], axis=1)
L_Crime.head()
# Out:
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0         39         30         23         25         28         20
# 1         33         57         45         36         55         37
# 2         31         24         20         19         29         26
# 3         29         28         37         27         40         41
# 4         28         40         33         37         36         18
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0         24         31         27         21         32
# 1         51         41         51         48         51
# 2         27         22         27         28         35
# 3         44         27         35         33         27
# 4         24         29         51         55         53

# %%
L_Crime = L_Crime.append(L_Crime.agg(['sum']))

# %%
L_Crime.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 95           0          0          0          0          0          0
# 96           0          0          0          0          0          0
# 97           0          0          0          0          0          0
# 98           0          0          0          0          0          0
# sum        686        745        690        745        761        663
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 95           0          0          0          0          7
# 96           4          6          5          7          8
# 97           0          0          4          6          9
# 98           0         17         21         26         15
# sum        734        701        728        777        898

# %%
head1=(L_Crime.loc['sum'])

# %%
head1.head(11)
# Out:
# 2005-2006    686
# 2006-2007    745
# 2007-2008    690
# 2008-2009    745
# 2009-2010    761
# 2010-2011    663
# 2011-2012    734
# 2012-2013    701
# 2013-2014    728
# 2014-2015    777
# 2015-2016    898
# Name: sum, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = head1
s.plot.bar()

plt.show()

# %%
s.plot.line()
plt.show()
