# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
Crime = pd.read_csv (r'SouthAfricaCrimeStats_v2.csv')

# %%
Crime.head()
# Out:
#        Province            Station                           Category  \
# 0  Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1       Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2  Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3    Free State          Park Road  All theft not mentioned elsewhere
# 4       Gauteng   Pretoria Central  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       6093       4602       3761       3610       3267       3037
# 2       5341       6093       6316       6803       6035       5761
# 3       5108       4282       3834       3316       3101       3013
# 4       5099       4536       3309       2694       2616       2606
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0       5285       5937       5600       5335       5176
# ...

# %%
FS_Crime = Crime[Crime["Category"]=="Murder"] # Extracting KZN in the Dataset
FS_Crime.head(10)
# Out:
#            Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 2028   Western Cape       Nyanga   Murder        282        302        266
# 2379  Kwazulu/Natal      Ntuzuma   Murder        241        254        236
# 2407  Kwazulu/Natal       Inanda   Murder        239        215        192
# 2548   Eastern Cape      Mthatha   Murder        223        143        149
# 2584   Western Cape  Khayelitsha   Murder        219        198        171
# 2893  Kwazulu/Natal       Umlazi   Murder        195        218        194
# 3463  Kwazulu/Natal   Esikhaleni   Murder        157        117         79
# 3560   Western Cape    Gugulethu   Murder        153        161        153
# 3749   Western Cape       Harare   Murder        143        168        175
# 3867  Kwazulu/Natal  Plessislaer   Murder        137        116        130
#
#       2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# ...

# %%
F_Crime = FS_Crime[FS_Crime["Province"]=="Free State"] # Extracting KZN in the Dataset
F_Crime.head(10)
# Out:
#          Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 5747   Free State      Thabong   Murder         79         67         68
# 7314   Free State  Bloemspruit   Murder         54         67         63
# 8753   Free State    Sasolburg   Murder         38         37         23
# 9255   Free State     Mangaung   Murder         34         26         26
# 9700   Free State   Kagisanong   Murder         31         39         27
# 10011  Free State       Welkom   Murder         29         25         29
# 10071  Free State      Maokeng   Murder         28         32         23
# 10515  Free State     Kopanong   Murder         26         43         41
# 10619  Free State    Selosesha   Murder         25         16          8
# 10648  Free State     Boithuso   Murder         25         34         27
#
#        2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 5747          49         52         62         76         78         75
# ...

# %%
F_Crime.to_csv(r'C:\Users\PHIRIME\Desktop\Phirie\FreeSMurder.csv')

# %%
F_Crime = pd.read_csv('FreeSMurder.csv')

# %%
F_Crime.shape
# Out:
# (110, 15)

# %%
F_Crime.head()
# Out:
#    Unnamed: 0    Province      Station Category  2005-2006  2006-2007  \
# 0        5747  Free State      Thabong   Murder         79         67
# 1        7314  Free State  Bloemspruit   Murder         54         67
# 2        8753  Free State    Sasolburg   Murder         38         37
# 3        9255  Free State     Mangaung   Murder         34         26
# 4        9700  Free State   Kagisanong   Murder         31         39
#
#    2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  \
# 0         68         49         52         62         76         78
# 1         63         68         76         79         74         76
# 2         23         31         26         31          3          5
# 3         26         27         25         33         21         24
# 4         27         37         35         33         40         32
#
#    2013-2014  2014-2015  2015-2016
# 0         75         69         76
# 1         76         89         71
# ...

# %%
F_Crimex=F_Crime.drop(['Station','Unnamed: 0','Province','Category'], axis=1)
F_Crimex.head()
# Out:
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0         79         67         68         49         52         62
# 1         54         67         63         68         76         79
# 2         38         37         23         31         26         31
# 3         34         26         26         27         25         33
# 4         31         39         27         37         35         33
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0         76         78         75         69         76
# 1         74         76         76         89         71
# 2          3          5          3          1          4
# 3         21         24         19         24         22
# 4         40         32         27         31         35

# %%
F_Crimex = F_Crimex.append(F_Crimex.agg(['sum']))

# %%
F_Crimex.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 106          0          1          0          3          4          0
# 107          0          4          2          2          2          4
# 108          0          1          0          2          2          0
# 109          0          0          0          0          0          0
# sum        860        944        863        901        900        958
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 106          0          0          0          2          1
# 107          1          2          2          3          1
# 108          0          0          1          0          2
# 109         27         27         17         24         20
# sum        954       1019        942        943        993

# %%
head1=(F_Crimex.loc['sum'])

# %%
head1.head(11)
# Out:
# 2005-2006     860
# 2006-2007     944
# 2007-2008     863
# 2008-2009     901
# 2009-2010     900
# 2010-2011     958
# 2011-2012     954
# 2012-2013    1019
# 2013-2014     942
# 2014-2015     943
# 2015-2016     993
# Name: sum, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = head1
s.plot.bar()

plt.show()

# %%
s.plot.line()
plt.show()
