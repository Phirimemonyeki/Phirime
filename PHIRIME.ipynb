# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
import io

# %%
Crime = pd.read_csv (r'SouthAfricaCrimeStats_v2.csv')

# %%
Crime.head(5)
# Out:
#        Province            Station                           Category  \
# 0  Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1       Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2  Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3    Free State          Park Road  All theft not mentioned elsewhere
# 4       Gauteng   Pretoria Central  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       6093       4602       3761       3610       3267       3037
# 2       5341       6093       6316       6803       6035       5761
# 3       5108       4282       3834       3316       3101       3013
# 4       5099       4536       3309       2694       2616       2606
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0       5285       5937       5600       5335       5176
# ...

# %%
Crime.Province.nunique() # Number of provinces in the dataset
# Out:
# 9

# %%
color = sns.color_palette()
cnt_srs = Crime.Province.value_counts()

plt.figure(figsize=(12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Crime', fontsize=12)
plt.xlabel(' SA Provinces', fontsize=12)
plt.title('SA provinces and thier crime', fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
K_Crime = Crime[Crime["Province"]=="Kwazulu/Natal"] # Extracting KZN in the Dataset
K_Crime.head(10)
# Out:
#           Province         Station                                Category  \
# 6    Kwazulu/Natal  Durban Central       All theft not mentioned elsewhere
# 17   Kwazulu/Natal  Durban Central  Robbery with aggravating circumstances
# 34   Kwazulu/Natal        Pinetown       All theft not mentioned elsewhere
# 48   Kwazulu/Natal         Phoenix                      Drug-related crime
# 51   Kwazulu/Natal  Durban Central   Theft of motor vehicle and motorcycle
# 54   Kwazulu/Natal         Phoenix                          Common assault
# 63   Kwazulu/Natal  Durban Central                             Shoplifting
# 75   Kwazulu/Natal         Phoenix       All theft not mentioned elsewhere
# 98   Kwazulu/Natal       Ladysmith       All theft not mentioned elsewhere
# 109  Kwazulu/Natal           Point       All theft not mentioned elsewhere
#
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 6         4162       4529       3499       3353       3183       2933
# ...

# %%
M_Crime = pd.read_csv (r'KZN.csv') # Focusing on murder
M_Crime.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1       Province      Station Category  2005-2006  \
# 0           1          2379  Kwazulu/Natal      Ntuzuma   Murder        241
# 1           2          2407  Kwazulu/Natal       Inanda   Murder        239
# 2           5          2893  Kwazulu/Natal       Umlazi   Murder        195
# 3           6          3463  Kwazulu/Natal   Esikhaleni   Murder        157
# 4           9          3867  Kwazulu/Natal  Plessislaer   Murder        137
#
#    2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  \
# 0        254        236        300        235         97         76
# 1        215        192        227        175        156        157
# 2        218        194        243        175        139        144
# 3        117         79         78         45         53         36
# 4        116        130        133        138        124         91
#
#    2012-2013  2013-2014  2014-2015  2015-2016
# 0         64         64         97         76
# ...

# %%
M_Crime.to_csv(r'C:\Users\PHIRIME\Desktop\Phirie\KZN_Murder.csv')

# %%
data=pd.read_csv('KZN_Murder.csv')

# %%
data.shape
# Out:
# (186, 17)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1       Province      Station  \
# 0           0             1            2379  Kwazulu/Natal      Ntuzuma
# 1           1             2            2407  Kwazulu/Natal       Inanda
# 2           2             5            2893  Kwazulu/Natal       Umlazi
# 3           3             6            3463  Kwazulu/Natal   Esikhaleni
# 4           4             9            3867  Kwazulu/Natal  Plessislaer
#
#   Category  2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0   Murder        241        254        236        300        235         97
# 1   Murder        239        215        192        227        175        156
# 2   Murder        195        218        194        243        175        139
# 3   Murder        157        117         79         78         45         53
# 4   Murder        137        116        130        133        138        124
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# ...

# %%
datax=data.drop(['Station','Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1','Province','Category'], axis=1)

# %%
datax.head()
# Out:
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0        241        254        236        300        235         97
# 1        239        215        192        227        175        156
# 2        195        218        194        243        175        139
# 3        157        117         79         78         45         53
# 4        137        116        130        133        138        124
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0         76         64         64         97         76
# 1        157        170        164        179        169
# 2        144        122        133        170        155
# 3         36         53         52         51         45
# 4         91        105         92         87         94

# %%
datax = datax.append(datax.agg(['sum']))

# %%
datax.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 182          0          1          0          2          1          1
# 183          0          6          1          1          3          4
# 184          0          1          1          1          4          1
# 185          0          0          0          0          0         78
# sum       4891       4984       4686       4737       4214       3740
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 182          1          2          2          1          2
# 183          6          1          3          2          3
# 184          0          2          0          0          4
# 185        114        120        128        107        128
# sum       3418       3623       3616       3810       3929

# %%
head1=(datax.loc['sum'])

# %%
head1.head(11)
# Out:
# 2005-2006    4891
# 2006-2007    4984
# 2007-2008    4686
# 2008-2009    4737
# 2009-2010    4214
# 2010-2011    3740
# 2011-2012    3418
# 2012-2013    3623
# 2013-2014    3616
# 2014-2015    3810
# 2015-2016    3929
# Name: sum, dtype: int64

# %%
s = head1
s.plot.bar()

plt.show()

# %%
s.plot.line()
plt.show()

# %%
K_Crime = Crime[Crime["Province"]=="Kwazulu/Natal"]
K_Crime.head()
# Out:
#          Province         Station                                Category  \
# 6   Kwazulu/Natal  Durban Central       All theft not mentioned elsewhere
# 17  Kwazulu/Natal  Durban Central  Robbery with aggravating circumstances
# 34  Kwazulu/Natal        Pinetown       All theft not mentioned elsewhere
# 48  Kwazulu/Natal         Phoenix                      Drug-related crime
# 51  Kwazulu/Natal  Durban Central   Theft of motor vehicle and motorcycle
#
#     2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 6        4162       4529       3499       3353       3183       2933
# 17       2721       3214       2134       1966       1371        899
# 34       2143       1934       1422       1331       1379       1362
# 48       1950       1809       1270        622       1085       1180
# 51       1919       1842       1267       1151        873        670
#
#     2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# ...

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
Crime = pd.read_csv (r'MurderSS.csv', index_col ='Date')

# %%
Crime.head(11)
# Out:
#             Sum
# Date
# 2005-2006  4891
# 2006-2007  4984
# 2007-2008  4686
# 2008-2009  4737
# 2009-2010  4214
# 2010-2011  3740
# 2011-2012  3418
# 2012-2013  3623
# 2013-2014  3616
# 2014-2015  3810
