# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
Crime = pd.read_csv (r'SouthAfricaCrimeStats_v2.csv')

# %%
Crime.head(10)
# Out:
#         Province            Station                           Category  \
# 0   Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1        Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2   Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3     Free State          Park Road  All theft not mentioned elsewhere
# 4        Gauteng   Pretoria Central  All theft not mentioned elsewhere
# 5     North West         Rustenburg  All theft not mentioned elsewhere
# 6  Kwazulu/Natal     Durban Central  All theft not mentioned elsewhere
# 7        Gauteng           Brooklyn  All theft not mentioned elsewhere
# 8        Gauteng           Booysens  All theft not mentioned elsewhere
# 9        Gauteng           Hillbrow  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# ...

# %%
K_Crime = Crime[Crime["Category"]=="Murder"]
K_Crime.head(10)
# Out:
#            Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 2028   Western Cape       Nyanga   Murder        282        302        266
# 2379  Kwazulu/Natal      Ntuzuma   Murder        241        254        236
# 2407  Kwazulu/Natal       Inanda   Murder        239        215        192
# 2548   Eastern Cape      Mthatha   Murder        223        143        149
# 2584   Western Cape  Khayelitsha   Murder        219        198        171
# 2893  Kwazulu/Natal       Umlazi   Murder        195        218        194
# 3463  Kwazulu/Natal   Esikhaleni   Murder        157        117         79
# 3560   Western Cape    Gugulethu   Murder        153        161        153
# 3749   Western Cape       Harare   Murder        143        168        175
# 3867  Kwazulu/Natal  Plessislaer   Murder        137        116        130
#
#       2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# ...

# %%
L_Crime = K_Crime[K_Crime["Province"]=="Northern Cape"] # Extracting KZN in the Dataset
L_Crime.head(10)
# Out:
#             Province    Station Category  2005-2006  2006-2007  2007-2008  \
# 7976   Northern Cape  Galeshewe   Murder         46         64         63
# 10214  Northern Cape  Kimberley   Murder         27         24         23
# 10568  Northern Cape   Rosedale   Murder         25         16         18
# 11301  Northern Cape    Kakamas   Murder         21         18         19
# 11489  Northern Cape    Douglas   Murder         20         11         18
# 12443  Northern Cape   Upington   Murder         16         17         14
# 13316  Northern Cape   Roodepan   Murder         13          9         15
# 14420  Northern Cape    Sunrise   Murder         10         11         18
# 14448  Northern Cape    Prieska   Murder         10         18          8
# 14682  Northern Cape  Pabalello   Murder          9          7          7
#
#        2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 7976          50         24         22         22         24         37
# ...

# %%
L_Crime.to_csv(r'C:\Users\PHIRIME\Desktop\Phirie\NortnCapeMurder.csv')

# %%
Crime = pd.read_csv('NortnCapeMurder.csv')

# %%
Crime.head()
# Out:
#    Unnamed: 0       Province    Station Category  2005-2006  2006-2007  \
# 0        7976  Northern Cape  Galeshewe   Murder         46         64
# 1       10214  Northern Cape  Kimberley   Murder         27         24
# 2       10568  Northern Cape   Rosedale   Murder         25         16
# 3       11301  Northern Cape    Kakamas   Murder         21         18
# 4       11489  Northern Cape    Douglas   Murder         20         11
#
#    2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  \
# 0         63         50         24         22         22         24
# 1         23         27         16         20         17         16
# 2         18          8         19         16         11         21
# 3         19         12          7          3          6          8
# 4         18          5         10          6         11         14
#
#    2013-2014  2014-2015  2015-2016
# 0         37         36         22
# 1         19         17         12
# ...

# %%
Crime.shape
# Out:
# (91, 15)

# %%
Crime.head()
# Out:
#    Unnamed: 0       Province    Station Category  2005-2006  2006-2007  \
# 0        7976  Northern Cape  Galeshewe   Murder         46         64
# 1       10214  Northern Cape  Kimberley   Murder         27         24
# 2       10568  Northern Cape   Rosedale   Murder         25         16
# 3       11301  Northern Cape    Kakamas   Murder         21         18
# 4       11489  Northern Cape    Douglas   Murder         20         11
#
#    2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  \
# 0         63         50         24         22         22         24
# 1         23         27         16         20         17         16
# 2         18          8         19         16         11         21
# 3         19         12          7          3          6          8
# 4         18          5         10          6         11         14
#
#    2013-2014  2014-2015  2015-2016
# 0         37         36         22
# 1         19         17         12
# ...

# %%
NC_Crimex=Crime.drop(['Station','Unnamed: 0','Province','Category'], axis=1)
NC_Crimex.head()
# Out:
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0         46         64         63         50         24         22
# 1         27         24         23         27         16         20
# 2         25         16         18          8         19         16
# 3         21         18         19         12          7          3
# 4         20         11         18          5         10          6
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0         22         24         37         36         22
# 1         17         16         19         17         12
# 2         11         21         10         15          8
# 3          6          8          8          9          6
# 4         11         14         10          8          6

# %%
NC_Crimex = NC_Crimex.append(NC_Crimex.agg(['sum']))

# %%
NC_Crimex.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 87           0          2          1          1          2          3
# 88           0          3          3          0          5          3
# 89           0          0          0          0          8          7
# 90           0          0          0         17         18         16
# sum        390        412        418        411        375        339
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 87           0          0          3          2          4
# 88           1          7          2          3          7
# 89           5          8          6         11          8
# 90          16         14         12         15         18
# sum        366        412        437        413        372

# %%
head1=(NC_Crimex.loc['sum'])

# %%
head1.head(11)
# Out:
# 2005-2006    390
# 2006-2007    412
# 2007-2008    418
# 2008-2009    411
# 2009-2010    375
# 2010-2011    339
# 2011-2012    366
# 2012-2013    412
# 2013-2014    437
# 2014-2015    413
# 2015-2016    372
# Name: sum, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = head1
s.plot.bar()

plt.show()

# %%
s.plot.line()
plt.show()
