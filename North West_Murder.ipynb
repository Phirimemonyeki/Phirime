# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
Crime = pd.read_csv (r'SouthAfricaCrimeStats_v2.csv')

# %%
Crime.head(10)
# Out:
#         Province            Station                           Category  \
# 0   Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1        Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2   Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3     Free State          Park Road  All theft not mentioned elsewhere
# 4        Gauteng   Pretoria Central  All theft not mentioned elsewhere
# 5     North West         Rustenburg  All theft not mentioned elsewhere
# 6  Kwazulu/Natal     Durban Central  All theft not mentioned elsewhere
# 7        Gauteng           Brooklyn  All theft not mentioned elsewhere
# 8        Gauteng           Booysens  All theft not mentioned elsewhere
# 9        Gauteng           Hillbrow  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# ...

# %%
K_Crime = Crime[Crime["Category"]=="Murder"]
K_Crime.head(10)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
#            Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 2028   Western Cape       Nyanga   Murder        282        302        266
# 2379  Kwazulu/Natal      Ntuzuma   Murder        241        254        236
# 2407  Kwazulu/Natal       Inanda   Murder        239        215        192
# 2548   Eastern Cape      Mthatha   Murder        223        143        149
# 2584   Western Cape  Khayelitsha   Murder        219        198        171
# 2893  Kwazulu/Natal       Umlazi   Murder        195        218        194
# 3463  Kwazulu/Natal   Esikhaleni   Murder        157        117         79
# 3560   Western Cape    Gugulethu   Murder        153        161        153
# 3749   Western Cape       Harare   Murder        143        168        175
# 3867  Kwazulu/Natal  Plessislaer   Murder        137        116        130
#
# ...

# %%
G_Crime = K_Crime[K_Crime["Province"]=="North West"] # Extracting KZN in the Dataset
G_Crime.head(10)
# Out:
#          Province     Station Category  2005-2006  2006-2007  2007-2008  \
# 7003   North West  Rustenburg   Murder         58         68         88
# 7810   North West      Kanana   Murder         48         44         31
# 7909   North West   Jouberton   Murder         47         60         54
# 9563   North West     Phokeng   Murder         32         39         44
# 9971   North West     Ikageng   Murder         29         31         33
# 10196  North West    Bethanie   Murder         27         16          8
# 10294  North West       Khuma   Murder         27         15          9
# 10753  North West    Tlhabane   Murder         24         26         44
# 10891  North West   Boitekong   Murder         24         21         25
# 11029  North West       Brits   Murder         23         24         29
#
#        2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 7003          86         68         48         45         54         48
# ...

# %%
G_Crime.to_csv(r'C:\Users\PHIRIME\Desktop\Phirie\NEgMurder.csv')

# %%
Crime = pd.read_csv('NEgMurder.csv')

# %%
Crime.head()
# Out:
#    Unnamed: 0    Province     Station Category  2005-2006  2006-2007  \
# 0        7003  North West  Rustenburg   Murder         58         68
# 1        7810  North West      Kanana   Murder         48         44
# 2        7909  North West   Jouberton   Murder         47         60
# 3        9563  North West     Phokeng   Murder         32         39
# 4        9971  North West     Ikageng   Murder         29         31
#
#    2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  \
# 0         88         86         68         48         45         54
# 1         31         29         38         21         27         26
# 2         54         51         39         60         44         46
# 3         44         46         46         37         30         37
# 4         33         31         39         26         28         27
#
#    2013-2014  2014-2015  2015-2016
# 0         48         53         68
# 1         29         41         41
# ...

# %%
Crime.shape
# Out:
# (82, 15)

# %%
Crime.head()
# Out:
#    Unnamed: 0    Province     Station Category  2005-2006  2006-2007  \
# 0        7003  North West  Rustenburg   Murder         58         68
# 1        7810  North West      Kanana   Murder         48         44
# 2        7909  North West   Jouberton   Murder         47         60
# 3        9563  North West     Phokeng   Murder         32         39
# 4        9971  North West     Ikageng   Murder         29         31
#
#    2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  \
# 0         88         86         68         48         45         54
# 1         31         29         38         21         27         26
# 2         54         51         39         60         44         46
# 3         44         46         46         37         30         37
# 4         33         31         39         26         28         27
#
#    2013-2014  2014-2015  2015-2016
# 0         48         53         68
# 1         29         41         41
# ...

# %%
N_Crime=Crime.drop(['Station','Unnamed: 0','Province','Category'], axis=1)
N_Crime.head()
# Out:
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0         58         68         88         86         68         48
# 1         48         44         31         29         38         21
# 2         47         60         54         51         39         60
# 3         32         39         44         46         46         37
# 4         29         31         33         31         39         26
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0         45         54         48         53         68
# 1         27         26         29         41         41
# 2         44         46         46         56         39
# 3         30         37         56         40         36
# 4         28         27         23         20         27

# %%
N_Crime = N_Crime.append(N_Crime.agg(['sum']))

# %%
N_Crime.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 78           0          0          1          1          0          2
# 79           0          1          4          6          3          2
# 80           0          4          7          7          6          5
# 81           0          0          0          0          0          0
# sum        750        822        824        853        741        743
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 78           1          2          2          1          5
# 79           2          6          2          3          5
# 80           5          6          5          6          9
# 81           6          6          8         12         12
# sum        799        867        824        853        907

# %%
head1=(N_Crime.loc['sum'])

# %%
head1.head(11)
# Out:
# 2005-2006    750
# 2006-2007    822
# 2007-2008    824
# 2008-2009    853
# 2009-2010    741
# 2010-2011    743
# 2011-2012    799
# 2012-2013    867
# 2013-2014    824
# 2014-2015    853
# 2015-2016    907
# Name: sum, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = head1
s.plot.bar()

plt.show()

# %%
s.plot.line()
plt.show()
