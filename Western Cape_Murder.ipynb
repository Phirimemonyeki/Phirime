# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
Crime = pd.read_csv (r'SouthAfricaCrimeStats_v2.csv')

# %%
Crime.head()
# Out:
#        Province            Station                           Category  \
# 0  Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1       Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2  Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3    Free State          Park Road  All theft not mentioned elsewhere
# 4       Gauteng   Pretoria Central  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       6093       4602       3761       3610       3267       3037
# 2       5341       6093       6316       6803       6035       5761
# 3       5108       4282       3834       3316       3101       3013
# 4       5099       4536       3309       2694       2616       2606
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0       5285       5937       5600       5335       5176
# ...

# %%
K_Crime = Crime[Crime["Category"]=="Murder"]
K_Crime.head(10)
# Out:
#            Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 2028   Western Cape       Nyanga   Murder        282        302        266
# 2379  Kwazulu/Natal      Ntuzuma   Murder        241        254        236
# 2407  Kwazulu/Natal       Inanda   Murder        239        215        192
# 2548   Eastern Cape      Mthatha   Murder        223        143        149
# 2584   Western Cape  Khayelitsha   Murder        219        198        171
# 2893  Kwazulu/Natal       Umlazi   Murder        195        218        194
# 3463  Kwazulu/Natal   Esikhaleni   Murder        157        117         79
# 3560   Western Cape    Gugulethu   Murder        153        161        153
# 3749   Western Cape       Harare   Murder        143        168        175
# 3867  Kwazulu/Natal  Plessislaer   Murder        137        116        130
#
#       2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# ...

# %%
G_Crime = K_Crime[K_Crime["Province"]=="Western Cape"] # Extracting KZN in the Dataset
G_Crime.head(10)
# Out:
#           Province        Station Category  2005-2006  2006-2007  2007-2008  \
# 2028  Western Cape         Nyanga   Murder        282        302        266
# 2584  Western Cape    Khayelitsha   Murder        219        198        171
# 3560  Western Cape      Gugulethu   Murder        153        161        153
# 3749  Western Cape         Harare   Murder        143        168        175
# 4507  Western Cape   Kraaifontein   Murder        113        113        118
# 5379  Western Cape          Delft   Murder         87        114        122
# 6500  Western Cape          Langa   Murder         65         67         59
# 6796  Western Cape  Philippi East   Murder         61         62         75
# 6801  Western Cape        Mfuleni   Murder         61         97        109
# 7584  Western Cape         Strand   Murder         50         70         73
#
#       2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# ...

# %%
G_Crime.to_csv(r'C:\Users\PHIRIME\Desktop\Phirie\WesternCCapeMurder.csv')

# %%
G_Crime = pd.read_csv('WesternCCapeMurder.csv')

# %%
G_Crime.shape
# Out:
# (150, 15)

# %%
G_Crime.head()
# Out:
#    Unnamed: 0      Province       Station Category  2005-2006  2006-2007  \
# 0        2028  Western Cape        Nyanga   Murder        282        302
# 1        2584  Western Cape   Khayelitsha   Murder        219        198
# 2        3560  Western Cape     Gugulethu   Murder        153        161
# 3        3749  Western Cape        Harare   Murder        143        168
# 4        4507  Western Cape  Kraaifontein   Murder        113        113
#
#    2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  \
# 0        266        206        215        197        232        261
# 1        171        121        124        124        160        168
# 2        153        135        110        150        120        129
# 3        175        119        118        141        154        131
# 4        118        100         77         78         94        121
#
#    2013-2014  2014-2015  2015-2016
# 0        305        300        279
# 1        146        146        161
# ...

# %%
W_Crimex=G_Crime.drop(['Station','Unnamed: 0','Province','Category'], axis=1)
W_Crimex.head()
# Out:
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0        282        302        266        206        215        197
# 1        219        198        171        121        124        124
# 2        153        161        153        135        110        150
# 3        143        168        175        119        118        141
# 4        113        113        118        100         77         78
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0        232        261        305        300        279
# 1        160        168        146        146        161
# 2        120        129        149        165        184
# 3        154        131        164        141        166
# 4         94        121        112        141        152

# %%
W_Crimex.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 145          0          3          2          2          4          3
# 146          0          0          1          2          0          3
# 147          0          0          1          5          8         11
# 148          0          0          0         29         32         31
# 149          0          0          0          0          0          0
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 145          1          2          2          3          2
# 146          3          1          0          1          3
# 147         14         26         34         30         36
# 148         48         38         46         38         44
# 149          0          0         13         40         51

# %%
W_Crimex = W_Crimex.append(W_Crimex.agg(['sum']))

# %%
W_Crimex.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 146          0          0          1          2          0          3
# 147          0          0          1          5          8         11
# 148          0          0          0         29         32         31
# 149          0          0          0          0          0          0
# sum       2741       2876       2835       2343       2271       2308
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 146          3          1          0          1          3
# 147         14         26         34         30         36
# 148         48         38         46         38         44
# 149          0          0         13         40         51
# sum       2293       2575       2904       3186       3224

# %%
head1=(W_Crimex.loc['sum'])

# %%
head1.head(11)
# Out:
# 2005-2006    2741
# 2006-2007    2876
# 2007-2008    2835
# 2008-2009    2343
# 2009-2010    2271
# 2010-2011    2308
# 2011-2012    2293
# 2012-2013    2575
# 2013-2014    2904
# 2014-2015    3186
# 2015-2016    3224
# Name: sum, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = head1
s.plot.bar()

plt.show()

# %%
s.plot.line()
plt.show()
