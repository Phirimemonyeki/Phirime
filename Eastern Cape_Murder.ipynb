# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
Crime = pd.read_csv (r'SouthAfricaCrimeStats_v2.csv')

# %%
Crime.head()
# Out:
#        Province            Station                           Category  \
# 0  Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1       Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2  Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3    Free State          Park Road  All theft not mentioned elsewhere
# 4       Gauteng   Pretoria Central  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       6093       4602       3761       3610       3267       3037
# 2       5341       6093       6316       6803       6035       5761
# 3       5108       4282       3834       3316       3101       3013
# 4       5099       4536       3309       2694       2616       2606
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0       5285       5937       5600       5335       5176
# ...

# %%
K_Crime = Crime[Crime["Category"]=="Murder"]
K_Crime.head(10)
# Out:
#            Province      Station Category  2005-2006  2006-2007  2007-2008  \
# 2028   Western Cape       Nyanga   Murder        282        302        266
# 2379  Kwazulu/Natal      Ntuzuma   Murder        241        254        236
# 2407  Kwazulu/Natal       Inanda   Murder        239        215        192
# 2548   Eastern Cape      Mthatha   Murder        223        143        149
# 2584   Western Cape  Khayelitsha   Murder        219        198        171
# 2893  Kwazulu/Natal       Umlazi   Murder        195        218        194
# 3463  Kwazulu/Natal   Esikhaleni   Murder        157        117         79
# 3560   Western Cape    Gugulethu   Murder        153        161        153
# 3749   Western Cape       Harare   Murder        143        168        175
# 3867  Kwazulu/Natal  Plessislaer   Murder        137        116        130
#
#       2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# ...

# %%
G_Crime = K_Crime[K_Crime["Province"]=="Eastern Cape"] # Extracting KZN in the Dataset
G_Crime.head(10)
# Out:
#           Province         Station Category  2005-2006  2006-2007  2007-2008  \
# 2548  Eastern Cape         Mthatha   Murder        223        143        149
# 4049  Eastern Cape    New Brighton   Murder        129        113         97
# 4498  Eastern Cape       Kwazakele   Murder        113        133        104
# 4975  Eastern Cape      Lusikisiki   Murder         98         84         64
# 5299  Eastern Cape          Ngcobo   Murder         89         61         62
# 5786  Eastern Cape  Duncan Village   Murder         78         84        100
# 5837  Eastern Cape        Ngqeleni   Murder         77         58         48
# 6011  Eastern Cape         Mbizana   Murder         74         65         79
# 6037  Eastern Cape     Ngangelizwe   Murder         73         41         51
# 6090  Eastern Cape       Mdantsane   Murder         72         43         54
#
#       2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# ...

# %%
G_Crime.to_csv(r'C:\Users\PHIRIME\Desktop\Phirie\EasternCapeMurder.csv')

# %%
G_Crime = pd.read_csv('EasternCapeMurder.csv')

# %%
G_Crime.shape
# Out:
# (196, 15)

# %%
G_Crime.head()
# Out:
#    Unnamed: 0      Province       Station Category  2005-2006  2006-2007  \
# 0        2548  Eastern Cape       Mthatha   Murder        223        143
# 1        4049  Eastern Cape  New Brighton   Murder        129        113
# 2        4498  Eastern Cape     Kwazakele   Murder        113        133
# 3        4975  Eastern Cape    Lusikisiki   Murder         98         84
# 4        5299  Eastern Cape        Ngcobo   Murder         89         61
#
#    2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  \
# 0        149        135        139        142        151        144
# 1         97         73         82         90        115         78
# 2        104        114         70         85         98         71
# 3         64         80         77         90         80        109
# 4         62         64         62         82         79        104
#
#    2013-2014  2014-2015  2015-2016
# 0         40         92        122
# 1        102         90         69
# ...

# %%
G_Crimex=G_Crime.drop(['Station','Unnamed: 0','Province','Category'], axis=1)
G_Crimex.head()
# Out:
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0        223        143        149        135        139        142
# 1        129        113         97         73         82         90
# 2        113        133        104        114         70         85
# 3         98         84         64         80         77         90
# 4         89         61         62         64         62         82
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0        151        144         40         92        122
# 1        115         78        102         90         69
# 2         98         71         83         66        105
# 3         80        109        112        102        110
# 4         79        104         40         80         83

# %%
G_Crimex.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 191          0          8         29         21         16         22
# 192          0          0          0          0          0          0
# 193          0          0          0          0          0          0
# 194          0          0          0          0          0          0
# 195          0          0          0          0          0          0
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 191         13         22         17         17         17
# 192          0          0          5         26         21
# 193          0          0          0         19         32
# 194          0         19         26         22         32
# 195          0          0         53         39         37

# %%
G_Crimex = G_Crimex.append(G_Crimex.agg(['sum']))

# %%
G_Crimex.tail()
# Out:
#      2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 192          0          0          0          0          0          0
# 193          0          0          0          0          0          0
# 194          0          0          0          0          0          0
# 195          0          0          0          0          0          0
# sum       3653       3602       3510       3253       3212       3179
#
#      2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 192          0          0          5         26         21
# 193          0          0          0         19         32
# 194          0         19         26         22         32
# 195          0          0         53         39         37
# sum       3269       3335       3441       3321       3649

# %%
head1=(G_Crimex.loc['sum'])

# %%
head1.head(11)
# Out:
# 2005-2006    3653
# 2006-2007    3602
# 2007-2008    3510
# 2008-2009    3253
# 2009-2010    3212
# 2010-2011    3179
# 2011-2012    3269
# 2012-2013    3335
# 2013-2014    3441
# 2014-2015    3321
# 2015-2016    3649
# Name: sum, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = head1
s.plot.bar()

plt.show()

# %%
s.plot.line()
plt.show()
